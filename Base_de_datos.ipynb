# %%
# @title
import numpy as np
Points_to_eval_estandar = [(np.array([[-0.0276797 , -0.74901693, -1.08589169],
         [-0.02174294, -0.7060999 , -1.58107431]]),
  [(-0.1, -3.0), (0.05, -1.0)]),
 (np.array([[-0.04300019, -0.73159933, -1.57205086],
         [-0.03933611, -0.69752616, -2.26574148]]),
  [(-0.05, -2.5), (0.0, -1.0)]),
 (np.array([[-0.06078528, -0.78451951, -1.09032949],
         [-0.05816925, -0.8421728 , -1.52355502]]),
  [(0.0, -1.0), (-0.08, -3.0)]),
 (np.array([[-0.06910655, -0.5500084 , -1.64301178],
         [-0.07318883, -0.43591618, -2.34074516]]),
  [(0.0, -1.0), (-0.05, -3.0)]),
 (np.array([[-0.07506634, -0.75162888, -1.55206523],
         [-0.0779302 , -0.72624208, -2.25393567]]),
  [(0.0, -1.0), (-0.05, -3.0)]),
 (np.array([[-0.04191303, -0.87406542, -0.74701413],
         [-0.0527757 , -0.85398167, -1.0355772 ]]),
  [(0.0, -1.0), (-0.05, -3.0)]),
 (np.array([[-0.07325561, -0.76290973, -1.56734225],
         [-0.08526306, -0.72238428, -2.26654684]]),
  [(0.0, -1.0), (-0.04, -3.0)]),
 (np.array([[-0.02249461, -0.84215826, -0.78480365],
         [-0.03460548, -0.78763277, -1.04966441]]),
  [(-0.02, -1.0), (-0.08, -3.0)]),
 (np.array([[ 0.00368936, -0.85051334, -0.75442224],
         [-0.00966165, -0.79982662, -1.03147799]]),
  [(0.0, -1.0), (-0.08, -3.0)]),
 (np.array([[-0.00820699, -0.77876306, -1.04268994],
         [-0.01428657, -0.8259763 , -1.29375142]]),
  [(0.0, -1.0), (-0.1, -3.0)]),
 (np.array([[ 1.30459507e-04, -8.62000031e-01, -1.26692710e+00],
         [-3.93971135e-03, -7.82143547e-01, -1.33503144e+00]]),
  [(0.0, -0.5), (-0.07, -2.5)]),
 (np.array([[ 0.01926237, -0.87284612, -0.72613324],
         [0.01380724, -0.83047207, -1.00593899]]),
  [(0.0, -0.5), (-0.1, -3.5)]),
 (np.array([[ 0.02999782, -0.80501206, -0.8128106 ],
         [ 0.023785  , -0.79616387, -1.32487054]]),
  [(0.02, -1.0), (0.0, -3.0)]),
 (np.array([[ 0.0282331 , -0.81102833, -0.81888927],
         [ 0.02701325, -0.79977413, -1.32219985]]),
  [(0.0, -3.0), (0.0, -0.5)]),
 (np.array([[ 0.02381445, -0.7781836 , -0.82678535],
         [ 0.03474236, -0.74919652, -1.3275876 ]]),
  [(0.1, -3.0), (0.02, -1.0)]),
 (np.array([[ 0.01607194, -0.76006789, -0.85478592],
         [ 0.02185994, -0.76646215, -1.05556649]]),
  [(0.04, -3.0), (0.03, -1.0)]),
 (np.array([[ 0.0118167 , -0.71737316, -0.88684325],
         [ 0.03259561, -0.65493433, -1.38850122]]),
  [(0.1, -3.0), (0.09, -1.0)]),
 (np.array([[ 0.01750749, -0.71623705, -0.8926868 ],
         [ 0.05845106, -0.66909674, -1.82574326]]),
  [(0.1, -3.0), (0.12, -1.0)]),
 (np.array([[ 0.01850502, -0.78747428, -1.09273855],
         [ 0.03720091, -0.71826266, -1.35137003]]),
  [(0.1, -3.0), (0.07, -0.75)]),
 (np.array([[ 0.07043904, -0.70056356, -0.92150282],
         [ 0.08802293, -0.71669847, -1.5481567 ]]),
  [(0.15, -3.0), (0.06, -0.6)]),
 (np.array([[ 0.0864417 , -0.68374998, -0.93044916],
         [ 0.109255  , -0.68494357, -1.56481778]]),
  [(0.12, -3.0), (0.08, -0.7)]),
 (np.array([[ 0.14603415, -0.70202332, -1.11637446],
         [ 0.14882126, -0.63864394, -1.17399747]]),
  [(0.15, -3.0), (0.1, -0.8)]),
 (np.array([[ 0.14814536, -0.73315065, -1.12823803],
         [ 0.15785072, -0.77072818, -1.55720475]]),
  [(0.18, -3.0), (0.1, -1.0)]),
 (np.array([[ 0.18374259, -0.8860598 , -1.94137382],
         [ 0.18976493, -0.91147525, -2.13970914]]),
  [(0.18, -3.0), (0.12, -0.7)]),
 (np.array([[ 0.0808205 , -0.87950011, -0.8020069 ],
         [ 0.09542621, -0.8999481 , -0.98442678]]),
  [(0.22, -3.0), (0.15, -1.0)]),
 (np.array([[ 0.08472901, -0.84936546, -0.8402821 ],
         [ 0.11687403, -0.81023804, -1.08984672]]),
  [(0.25, -3.0), (0.2, -1.0)]),
 (np.array([[ 0.12290713, -0.86541779, -0.82823349],
         [ 0.14866992, -0.82158111, -1.06168574]]),
  [(0.25, -3.0), (0.12, -0.7)]),
 (np.array([[ 0.1800858 , -0.83474651, -1.30216394],
         [ 0.19130152, -0.84755166, -1.48402637]]),
  [(0.25, -2.5), (0.18, -0.7)]),
 (np.array([[ 0.17142918, -0.81749941, -0.87117871],
         [ 0.18032918, -0.74913546, -0.88666314]]),
  [(0.25, -3.0), (0.18, -1.0)]),
 (np.array([[ 0.18834446, -0.84955002, -0.80356615],
         [ 0.2244105 , -0.79973473, -1.29339222]]),
  [(0.25, -2.5), (0.14, -0.8)]),
 (np.array([[ 0.2203822 , -0.82086306, -1.27162519],
         [ 0.2325116 , -0.89384141, -1.68485536]]),
  [(0.25, -2.5), (0.15, -1.0)]),
 (np.array([[ 0.14247314, -0.88068819, -0.76794646],
         [ 0.15285782, -0.83262394, -0.82250072]]),
  [(0.25, -2.5), (0.2, -0.8)]),
 (np.array([[ 0.17734937, -0.73669242, -0.9022448 ],
         [ 0.20424947, -0.8486312 , -1.73577273]]),
  [(0.25, -3.0), (0.2, -1.0)]),
 (np.array([[ 0.10334627, -0.84699451, -0.82764767],
         [ 0.11592927, -0.87736192, -1.03086616]]),
  [(0.24, -2.5), (0.18, -1.0)]),
 (np.array([[ 0.09031057, -0.82693905, -0.84177512],
         [ 0.10344072, -0.77702537, -0.88902235]]),
  [(0.24, -2.5), (0.15, -0.75)]),
 (np.array([[ 0.08591474, -0.77069832, -1.08710217],
         [ 0.13657859, -0.75728195, -1.74694516]]),
  [(0.2, -3.0), (0.12, -1.0)]),
 (np.array([[ 0.09002813, -0.79794514, -0.86631096],
         [ 0.11124938, -0.85094932, -1.29253461]]),
  [(0.18, -3.0), (0.1, -0.9)]),
 (np.array([[ 0.06840754, -0.90073702, -0.79170357],
         [ 0.07908832, -0.8409902 , -0.82508031]]),
  [(0.15, -3.0), (0.11, -1.0)]),
 (np.array([[ 0.14231436, -0.80150109, -1.05539249],
         [ 0.14640454, -0.75801395, -1.12032335]]),
  [(0.14, -3.0), (0.12, -1.0)]),
 (np.array([[ 0.13532656, -0.74971866, -1.07951498],
         [ 0.13586014, -0.84498534, -1.72868859]]),
  [(0.12, -1.0), (0.15, -3.0)]),
 (np.array([[ 0.12614228, -0.8738087 , -1.2707741 ],
         [ 0.12452995, -0.87331393, -1.72366189]]),
  [(0.12, -3.0), (0.08, -0.6)]),
 (np.array([[ 0.09738193, -0.8424559 , -1.27624511],
         [ 0.10364792, -0.81270503, -1.53627549]]),
  [(0.13, -3.0), (0.1, -1.0)]),
 (np.array([[ 0.08744555, -0.84064198, -1.25489921],
         [ 0.097657  , -0.81476947, -1.52522618]]),
  [(0.12, -3.0), (0.13, -1.0)]),
 (np.array([[ 0.08084883, -0.84665365, -1.06059551],
         [ 0.09724007, -0.83785711, -1.5125022 ]]),
  [(0.1, -1.0), (0.15, -3.0)]),
 (np.array([[ 0.09036521, -0.83651129, -1.06017526],
         [ 0.11268115, -0.84176484, -1.70501211]]),
  [(0.12, -0.9), (0.14, -2.5)]),
 (np.array([[ 0.07697625, -0.84924434, -0.80034537],
         [ 0.08934116, -0.81510282, -1.05565318]]),
  [(0.12, -1.0), (0.15, -3.0)]),
 (np.array([[ 0.11533356, -0.71025587, -1.77401907],
         [ 0.12095917, -0.72171183, -1.98569177]]),
  [(0.13, -3.0), (0.1, -0.8)]),
 (np.array([[ 0.08988078, -0.80476027, -0.85518603],
         [ 0.10245645, -0.76333056, -1.3057094 ]]),
  [(0.13, -3.0), (0.08, -0.8)]),
 (np.array([[ 0.0873804 , -0.83314808, -0.80123629],
         [ 0.09099052, -0.77585292, -0.8693831 ]]),
  [(0.12, -2.5), (0.1, -1.0)]),
 (np.array([[ 0.09420038, -0.86330345, -0.78033732],
         [ 0.09515562, -0.78784538, -0.81947232]]),
  [(0.12, -3.0), (0.1, -0.75)]),
 (np.array([[ 0.09053043, -0.77490938, -0.82517103],
         [ 0.09232744, -0.83498347, -1.25441017]]),
  [(0.13, -3.0), (0.08, -1.0)]),
 (np.array([[ 0.10024939, -0.78597931, -1.75983396],
         [ 0.09890453, -0.80838642, -1.97190312]]),
  [(0.12, -3.0), (0.08, -1.0)]),
 (np.array([[ 0.09142075, -0.78921127, -1.5511981 ],
         [ 0.09033993, -0.80870485, -1.7556202 ]]),
  [(0.12, -2.5), (0.07, -0.8)]),
 (np.array([[ 0.09321675, -0.80159738, -1.075948  ],
         [ 0.09050567, -0.76957385, -1.54768201]]),
  [(0.1, -1.5), (0.11, -2.5)]),
 (np.array([[ 0.04965886, -0.79918078, -1.05601467],
         [ 0.06029468, -0.77161714, -1.53914058]]),
  [(0.13, -3.0), (0.1, -0.9)]),
 (np.array([[ 0.05145678, -0.79287742, -0.83509627],
         [ 0.05441694, -0.80879558, -1.0362677 ]]),
  [(0.1, -3.0), (0.08, -0.5)]),
 (np.array([[ 0.04087385, -0.78243655, -0.83458352],
         [ 0.04468196, -0.7978831 , -1.03835861]]),
  [(0.1, -3.0), (0.08, -0.5)]),
 (np.array([[ 0.02101741, -0.80421769, -0.8119523 ],
         [ 0.02669637, -0.8287125 , -1.02122285]]),
  [(0.1, -3.0), (0.05, -0.5)]),
 (np.array([[ 0.01369665, -0.82583173, -0.78705256],
         [ 0.02051293, -0.86432361, -1.00456502]]),
  [(0.05, -0.5), (0.1, -3.0)]),
 (np.array([[ 0.00975825, -0.84019565, -0.78038992],
         [ 0.01629215, -0.86868194, -0.98025653]]),
  [(0.02, -2.5), (0.08, -0.5)]),
 (np.array([[ 0.00666088, -0.84622733, -0.79319984],
         [ 0.01147276, -0.87035006, -0.98769106]]),
  [(0.07, -3.0), (0.06, -0.5)]),
 (np.array([[ 0.04240943, -0.8432866 , -1.00658435],
         [ 0.04346518, -0.84845974, -1.51021388]]),
  [(0.05, -2.5), (0.08, -0.5)]),
 (np.array([[ 0.03419883, -0.84944722, -1.0425201 ],
         [ 0.03614115, -0.83711606, -1.52194246]]),
  [(0.02, -3.0), (0.1, -0.5)]),
 (np.array([[ 0.02619172, -0.8207821 , -0.79613517],
         [ 0.02975127, -0.79237875, -1.08583236]]),
  [(0.0, -2.5), (0.1, -0.5)]),
 (np.array([[ 0.04251473, -0.82732185, -0.82175096],
         [ 0.04268219, -0.77975494, -1.08490188]]),
  [(0.03, -2.5), (0.05, -0.5)]),
 (np.array([[ 0.06502428, -0.81109014, -0.81807468],
         [ 0.06135385, -0.7614852 , -1.08210915]]),
  [(0.1, -3.0), (0.05, -0.7)]),
 (np.array([[ 0.0585798 , -0.78945125, -1.0526549 ],
         [ 0.05779824, -0.81481612, -1.27065323]]),
  [(0.05, -3.0), (0.03, -0.75)]),
 (np.array([[ 0.07780176, -0.75029459, -0.88129563],
         [ 0.07674491, -0.76942989, -1.09367359]]),
  [(0.1, -3.0), (0.05, -0.6)]),
 (np.array([[ 0.10789557, -0.74623467, -0.87431433],
         [ 0.10363795, -0.76192831, -1.07991079]]),
  [(0.1, -3.0), (0.05, -0.7)]),
 (np.array([[ 0.10977732, -0.74249979, -0.89634309],
         [ 0.09888936, -0.74856916, -1.77570606]]),
  [(0.1, -2.5), (0.08, -1.0)]),
 (np.array([[ 0.10627354, -0.82037735, -1.26388981],
         [ 0.1048946 , -0.87067279, -1.49869196]]),
  [(0.1, -2.5), (0.06, -0.5)]),
 (np.array([[ 0.12608285, -0.93663675, -1.22177902],
         [ 0.12507766, -0.97726081, -1.41160914]]),
  [(0.12, -2.5), (0.09, -1.0)]),
 (np.array([[ 0.12756358, -0.92586385, -1.21546086],
         [ 0.12658033, -0.96447313, -1.4062232 ]]),
  [(0.14, -2.5), (0.1, -0.5)]),
 (np.array([[ 0.13023782, -0.89429291, -1.70299361],
         [ 0.15353196, -0.92246076, -2.62324571]]),
  [(0.12, -1.0), (0.15, -2.5)]),
 (np.array([[ 0.08946284, -0.72308117, -0.90789012],
         [ 0.11896276, -0.71827919, -1.78419503]]),
  [(0.16, -2.5), (0.12, -1.0)]),
 (np.array([[ 0.13890264, -0.63896349, -1.79704616],
         [ 0.15739884, -0.60032335, -2.29469285]]),
  [(0.12, -1.0), (0.2, -3.0)]),
 (np.array([[ 0.11143621, -0.72287511, -1.13901549],
         [ 0.13979831, -0.67427797, -1.78301873]]),
  [(0.22, -3.0), (0.15, -1.0)]),
 (np.array([[ 0.1188013 , -0.72649767, -1.13413501],
         [ 0.13860138, -0.6806804 , -1.60140727]]),
  [(0.2, -2.5), (0.15, -1.0)]),
 (np.array([[ 0.13028441, -0.72311688, -1.11416394],
         [ 0.14557081, -0.68336311, -1.59753828]]),
  [(0.15, -1.0), (0.23, -3.5)]),
 (np.array([[ 0.12246993, -0.73274483, -0.90206876],
         [ 0.12996054, -0.74338456, -1.10620881]]),
  [(0.13, -1.0), (0.23, -3.0)]),
 (np.array([[ 0.12908184, -0.74124561, -0.88999712],
         [ 0.14889016, -0.71615105, -1.55975333]]),
  [(0.23, -3.0), (0.12, -1.0)]),
 (np.array([[ 0.13140978, -0.765335  , -1.07577187],
         [ 0.13699206, -0.78766918, -1.28247258]]),
  [(0.22, -3.0), (0.12, -1.0)]),
 (np.array([[ 0.1194567 , -0.81415419, -1.02197899],
         [ 0.12575048, -0.85427402, -1.23582545]]),
  [(0.13, -1.5), (0.2, -3.0)]),
 (np.array([[ 0.16890528, -0.8425997 , -1.26732052],
         [ 0.15567026, -0.9435017 , -2.18311921]]),
  [(0.22, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.17032873, -0.8044997 , -1.29381614],
         [ 0.16157938, -0.87309463, -2.21817599]]),
  [(0.11, -0.5), (0.22, -3.5)]),
 (np.array([[ 0.16806439, -0.7867488 , -1.30474126],
         [ 0.16270628, -0.81787717, -2.03431323]]),
  [(0.22, -3.5), (0.1, -0.6)]),
 (np.array([[ 0.17039898, -0.67810775, -0.90804793],
         [ 0.16915403, -0.72839125, -1.34192668]]),
  [(0.22, -3.0), (0.08, -0.5)]),
 (np.array([[ 0.07792635, -0.75211624, -0.86079563],
         [ 0.11106155, -0.73157161, -1.34832391]]),
  [(0.25, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.11205945, -0.72935096, -0.88969184],
         [ 0.13909788, -0.69106941, -1.37074401]]),
  [(0.25, -3.0), (0.12, -0.7)]),
 (np.array([[ 0.11470202, -0.71207502, -0.86989617],
         [ 0.12503257, -0.64356139, -0.94392564]]),
  [(0.26, -3.0), (0.12, -0.7)]),
 (np.array([[ 0.10393258, -0.67598076, -0.90545772],
         [ 0.15992399, -0.64841684, -1.60794355]]),
  [(0.25, -3.0), (0.12, -0.6)]),
 (np.array([[ 0.11170769, -0.6820659 , -0.87119185],
         [ 0.16945739, -0.66613628, -1.59912699]]),
  [(0.26, -3.0), (0.12, -0.65)]),
 (np.array([[ 0.18100815, -0.71887942, -1.79942501],
         [ 0.21657946, -0.67503402, -2.10430484]]),
  [(0.26, -2.5), (0.12, -0.55)]),
 (np.array([[ 0.08770331, -0.63729275, -0.93594781],
         [ 0.22290916, -0.65070721, -2.10980152]]),
  [(0.3, -3.0), (0.12, -0.5)]),
 (np.array([[ 0.07183855, -0.62220633, -0.90987001],
         [ 0.12315775, -0.67060057, -1.38478799]]),
  [(0.3, -3.0), (0.1, -0.5)]),
 (np.array([[ 0.08893659, -0.66403993, -0.88546131],
         [ 0.13742767, -0.71564453, -1.34344466]]),
  [(0.25, -2.0), (0.11, -0.5)]),
 (np.array([[ 0.16438151, -0.72391836, -1.33067734],
         [ 0.21941696, -0.7056805 , -1.82062048]]),
  [(0.25, -2.0), (0.12, -0.5)]),
 (np.array([[ 0.18943042, -0.71830196, -1.11380387],
         [ 0.21862472, -0.65501685, -1.38336439]]),
  [(0.25, -2.0), (0.1, -0.5)]),
 (np.array([[ 0.20068863, -0.71945463, -0.88179257],
         [ 0.23660578, -0.67725379, -1.37194228]]),
  [(0.25, -2.0), (0.12, -0.5)]),
 (np.array([[ 0.21603836, -0.70247069, -0.88179186],
         [ 0.24570127, -0.65770307, -1.37670367]]),
  [(0.25, -2.0), (0.1, -0.5)]),
 (np.array([[ 0.24466932, -0.60335925, -1.19196566],
         [ 0.25323242, -0.60791779, -1.40331511]]),
  [(0.25, -2.0), (0.15, -0.5)]),
 (np.array([[ 0.20704228, -0.72937783, -0.86285639],
         [ 0.21892168, -0.74685419, -1.0715236 ]]),
  [(0.25, -2.0), (0.16, -0.5)]),
 (np.array([[ 0.17548695, -0.74152278, -0.84359473],
         [ 0.20639224, -0.69810043, -1.12132255]]),
  [(0.26, -2.0), (0.14, -0.5)]),
 (np.array([[ 0.09952345, -0.75183382, -0.85023732],
         [ 0.20959214, -0.68617663, -1.59755865]]),
  [(0.27, -2.0), (0.13, -0.5)]),
 (np.array([[ 0.08653232, -0.75210557, -0.83880818],
         [ 0.13068762, -0.71548432, -1.12167399]]),
  [(0.27, -2.0), (0.11, -0.5)]),
 (np.array([[ 0.12191019, -0.70667083, -1.10182943],
         [ 0.18776296, -0.69686934, -1.60426015]]),
  [(0.28, -2.0), (0.08, -0.5)]),
 (np.array([[ 0.11398224, -0.62455283, -1.14490711],
         [ 0.17857393, -0.57202726, -1.63652258]]),
  [(0.26, -2.0), (0.1, -0.5)]),
 (np.array([[ 0.10772078, -0.68139926, -0.89993313],
         [ 0.14055933, -0.64142666, -1.1757502 ]]),
  [(0.28, -2.5), (0.11, -0.6)]),
 (np.array([[ 0.15265161, -0.753165  , -1.33155277],
         [ 0.25478317, -0.74695292, -2.47698721]]),
  [(0.28, -2.5), (0.12, -0.5)]),
 (np.array([[ 0.13593469, -0.77291835, -1.29758789],
         [ 0.26447123, -0.77983059, -2.9583056 ]]),
  [(0.25, -2.5), (0.1, -0.5)]),
 (np.array([[ 0.14349475, -0.73178154, -0.85020041],
         [ 0.1510722 , -0.66343674, -0.9073241 ]]),
  [(0.25, -2.5), (0.1, -0.5)]),
 (np.array([[ 0.17829786, -0.64181939, -0.90630447],
         [ 0.19353223, -0.74896662, -2.9680175 ]]),
  [(0.27, -3.0), (0.1, -0.5)]),
 (np.array([[ 0.05816457, -0.75505221, -0.85715607],
         [ 0.0862706 , -0.70889358, -1.10414592]]),
  [(0.24, -3.0), (0.1, -0.5)]),
 (np.array([[ 0.06462541, -0.74700438, -0.84164857],
         [ 0.09068145, -0.71407927, -1.12026109]]),
  [(0.24, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.06262189, -0.71792615, -0.87177993],
         [ 0.07640702, -0.7496352 , -1.07742771]]),
  [(0.23, -3.0), (0.08, -0.5)]),
 (np.array([[ 0.04973558, -0.814821  , -1.06245553],
         [ 0.16680873, -0.89675457, -2.23153777]]),
  [(0.2, -3.0), (0.07, -0.5)]),
 (np.array([[ 0.03529514, -0.68842711, -0.88552876],
         [ 0.16175683, -0.87260858, -2.22748545]]),
  [(0.22, -3.5), (0.05, -0.5)]),
 (np.array([[ 0.0728193 , -0.68389468, -0.90091937],
         [ 0.09048835, -0.65124835, -1.17000144]]),
  [(0.2, -3.5), (0.05, -0.5)]),
 (np.array([[ 0.06264412, -0.76912856, -1.06397845],
         [ 0.071732  , -0.69921929, -1.10502738]]),
  [(0.2, -3.5), (0.05, -0.5)]),
 (np.array([[ 0.08149192, -0.79010106, -0.79007763],
         [ 0.08613937, -0.85317417, -1.00800767]]),
  [(0.14, -3.0), (0.03, -0.5)]),
 (np.array([[ 0.07753633, -0.80202677, -0.79805638],
         [ 0.08193754, -0.84577109, -0.99134442]]),
  [(0.14, -3.0), (0.1, -0.5)]),
 (np.array([[ 0.08605365, -0.80440914, -1.27269755],
         [ 0.090005  , -0.75567405, -1.34603037]]),
  [(0.115, -3.0), (0.12, -0.5)]),
 (np.array([[ 0.06656145, -0.73101101, -1.33327275],
         [ 0.07683487, -0.80587685, -1.75815449]]),
  [(0.13, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.04769146, -0.71740741, -1.12077632],
         [ 0.059884  , -0.6015702 , -1.42297929]]),
  [(0.1, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.03861077, -0.72637847, -0.9052193 ],
         [ 0.06710305, -0.70636725, -2.02805782]]),
  [(0.1, -3.0), (0.09, -0.5)]),
 (np.array([[ 0.06613796, -0.74230833, -1.09968686],
         [ 0.06164348, -0.71068581, -2.01125548]]),
  [(0.12, -3.0), (0.08, -0.5)]),
 (np.array([[ 0.05919515, -0.72815429, -0.88097703],
         [ 0.0598027 , -0.66809438, -0.93548423]]),
  [(0.1, -3.0), (0.05, -0.5)]),
 (np.array([[ 0.03559855, -0.72061479, -0.86025028],
         [ 0.04043882, -0.71478925, -1.32346397]]),
  [(0.05, -3.0), (0.02, -0.5)]),
 (np.array([[ 0.017011  , -0.72800539, -1.13014715],
         [ 0.02143182, -0.65376803, -1.16547959]]),
  [(0.05, -3.0), (0.0, -0.5)]),
 (np.array([[-1.54535678e-02, -6.26684246e-01, -9.56515624e-01],
         [ 1.00180161e-03, -5.47422904e-01, -1.18194941e+00]]),
  [(0.05, -3.0), (0.01, -0.5)]),
 (np.array([[-4.46891817e-02, -6.18980864e-01, -9.45929488e-01],
         [-4.15094268e-04, -6.34692730e-01, -1.80177925e+00]]),
  [(0.05, -2.5), (0.0, -0.5)]),
 (np.array([[-0.04121855, -0.66122482, -0.89714491],
         [ 0.00209296, -0.72248109, -1.77218504]]),
  [(0.05, -2.5), (0.0, -0.5)]),
 (np.array([[-0.01143306, -0.6496817 , -0.91199906],
         [ 0.01596298, -0.68645936, -1.78413109]]),
  [(0.02, -3.0), (0.03, -0.5)]),
 (np.array([[ 0.0429275 , -0.79277159, -0.84166637],
         [ 0.04314941, -0.76363926, -1.33066083]]),
  [(0.05, -3.0), (0.06, -0.5)]),
 (np.array([[ 0.05344966, -0.80622395, -0.81623   ],
         [ 0.0509014 , -0.79252346, -1.27560044]]),
  [(0.03, -3.0), (0.05, -0.5)]),
 (np.array([[ 0.04767362, -0.80782778, -0.80476037],
         [ 0.04640263, -0.66718267, -0.921228  ]]),
  [(0.0, -3.5), (0.08, -0.5)]),
 (np.array([[ 0.05895223, -0.77675228, -0.82098048],
         [ 0.0595791 , -0.78456151, -1.31883394]]),
  [(0.1, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.05656259, -0.77765115, -1.30040161],
         [ 0.06035182, -0.8286283 , -1.53844258]]),
  [(0.1, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.0311398 , -0.67447755, -0.88122379],
         [ 0.03736729, -0.6019808 , -0.95049605]]),
  [(0.1, -3.0), (0.08, -0.5)]),
 (np.array([[ 0.05357493, -0.66217197, -1.63346523],
         [ 0.05952097, -0.68849678, -1.85992126]]),
  [(0.1, -2.5), (0.02, -0.5)]),
 (np.array([[ 0.05780087, -0.7706034 , -1.5836524 ],
         [ 0.06375385, -0.8031896 , -1.79768729]]),
  [(0.1, -0.5), (0.11, -3.5)]),
 (np.array([[ 0.05108255, -0.79061925, -1.03415396],
         [ 0.05612458, -0.84978584, -1.2702625 ]]),
  [(0.05, -0.5), (0.1, -3.0)]),
 (np.array([[ 0.08286288, -0.73591727, -0.85358214],
         [ 0.0840656 , -0.77456669, -1.07438264]]),
  [(0.08, -0.5), (0.1, -3.5)]),
 (np.array([[ 0.09159368, -0.88965388, -1.76055627],
         [ 0.09225388, -0.93577956, -1.96882547]]),
  [(0.12, -0.5), (0.13, -3.0)]),
 (np.array([[ 0.10639012, -0.75585051, -0.81434993],
         [ 0.09973829, -0.82615148, -1.55814045]]),
  [(0.08, -0.5), (0.1, -3.5)]),
 (np.array([[ 0.11414202, -0.74923666, -1.09769726],
         [ 0.11009867, -0.76782491, -1.31434111]]),
  [(0.1, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.12355697, -0.77986788, -1.31720256],
         [ 0.11232249, -0.70942658, -1.58816409]]),
  [(0.1, -0.5), (0.09, -3.5)]),
 (np.array([[ 0.10219069, -0.72286792, -0.86894804],
         [ 0.09847714, -0.75281062, -1.09403836]]),
  [(0.1, -3.5), (0.07, -0.5)]),
 (np.array([[ 0.07297206, -0.74598195, -0.8558541 ],
         [ 0.07161811, -0.73002435, -1.35900055]]),
  [(0.08, -3.0), (0.05, -0.5)]),
 (np.array([[ 0.06449669, -0.70839875, -0.86294377],
         [ 0.06475054, -0.73492042, -1.08204497]]),
  [(0.08, -0.5), (0.07, -3.0)]),
 (np.array([[ 0.07589019, -0.65365644, -1.86469087],
         [ 0.08034568, -0.60315196, -2.33583062]]),
  [(0.05, -0.5), (0.02, -3.5)]),
 (np.array([[ 0.043067  , -0.68136378, -0.91897393],
         [ 0.04824367, -0.70045566, -1.14117472]]),
  [(0.03, -0.5), (0.04, -3.5)]),
 (np.array([[ 0.06611382, -0.70229047, -0.90812523],
         [ 0.0789718 , -0.68742798, -1.82098033]]),
  [(0.05, -3.5), (0.04, -0.5)]),
 (np.array([[ 0.04878237, -0.73615946, -0.84012861],
         [ 0.05420854, -0.776232  , -1.06601016]]),
  [(0.05, -3.0), (0.06, -0.5)]),
 (np.array([[ 0.06459996, -0.80237499, -1.03797798],
         [ 0.06916199, -0.74292045, -1.11164232]]),
  [(0.1, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.09419938, -0.80677233, -1.02964968],
         [ 0.09687786, -0.76576246, -1.30224921]]),
  [(0.09, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.09968852, -0.75742667, -1.09182362],
         [ 0.10537467, -0.76868238, -2.29595668]]),
  [(0.12, -3.0), (0.15, -0.5)]),
 (np.array([[ 0.10935966, -0.42450227, -1.23017286],
         [ 0.1107034 , -0.0889586 , -2.39867137]]),
  [(0.12, -3.5), (0.13, -0.7)]),
 (np.array([[ 0.17028221, -1.55707521, -2.59611936],
         [ 0.13633934, -1.14149939, -1.15000253]]),
  [(0.12, -0.5), (0.13, -3.0)]),
 (np.array([[ 0.2043974 , -1.41070331, -2.36590961],
         [ 0.17918732, -1.33865715, -2.10040149]]),
  [(0.13, -3.0), (0.12, -0.5)]),
 (np.array([[ 0.1683298 , -1.07568432, -2.53712223],
         [ 0.07452611, -0.9218905 , -1.33035359]]),
  [(0.14, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.06453602, -1.01663417, -1.27091575],
         [ 0.12985213, -1.24377486, -2.47860928]]),
  [(0.14, -3.0), (0.14, -0.5)]),
 (np.array([[ 0.06378427, -0.65277536, -2.99213173],
         [ 0.08148496, -0.68161645, -2.06596177]]),
  [(0.08, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.07820404, -0.75629848, -1.15057095],
         [ 0.08535975, -0.74784881, -0.85063277]]),
  [(0.03, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.01502783, -0.92351722, -2.90905352],
         [ 0.02877078, -0.91605349, -2.63652071]]),
  [(0.03, -3.5), (0.1, -0.5)]),
 (np.array([[ 8.69073115e-02, -9.03536321e-01, -1.37458446e+00],
         [-1.79110106e-04, -1.04796345e+00, -2.90675808e+00]]),
  [(0.0, -3.5), (0.08, -0.5)]),
 (np.array([[ 0.10538212, -0.77177152, -1.43927362],
         [ 0.01421615, -0.7797747 , -2.97870752]]),
  [(0.02, -3.5), (0.07, -0.5)]),
 (np.array([[ 0.03591509, -0.88941883, -2.6431352 ],
         [ 0.06070232, -0.86327875, -2.331921  ]]),
  [(0.02, -3.5), (0.08, -0.5)]),
 (np.array([[ 0.0368823 , -0.57890892, -2.70846447],
         [ 0.0555216 , -0.57203927, -2.41789075]]),
  [(0.02, -3.5), (0.08, -0.5)]),
 (np.array([[ 0.05183323, -0.26986491, -2.74849666],
         [ 0.07832311, -0.53302504, -0.9977215 ]]),
  [(0.02, -3.5), (0.06, -0.5)]),
 (np.array([[ 0.07841746, -0.75776498, -2.61545326],
         [ 0.04403339, -0.74207029, -1.14646345]]),
  [(0.02, -3.5), (0.04, -0.5)]),
 (np.array([[ 0.13305698,  0.19071734, -3.04055603],
         [ 0.1053705 ,  0.02512357, -2.71028851]]),
  [(0.02, -3.5), (0.06, -0.5)]),
 (np.array([[ 0.06504599, -0.68748002, -1.16726278],
         [ 0.09540536, -0.67607143, -2.64987092]]),
  [(0.07, -3.5), (0.03, -0.5)]),
 (np.array([[ 0.09742895, -0.58611104, -2.63677847],
         [ 0.09389668, -0.6479503 , -1.20491647]]),
  [(0.11, -3.5), (0.05, -0.5)]),
 (np.array([[ 0.14692276, -0.62741685, -0.93756957],
         [ 0.12212806, -0.53729552, -1.81027471]]),
  [(0.13, -3.5), (0.09, -0.5)]),
 (np.array([[ 0.13525509, -1.03601763, -2.23662815],
         [ 0.16337664, -0.88507564, -1.03267897]]),
  [(0.13, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.15028797, -1.15012313, -2.19412097],
         [ 0.152641  , -0.93874073, -1.36759495]]),
  [(0.18, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.14784166, -0.8064105 , -1.10176293],
         [ 0.14416198, -0.75625159, -0.81715613]]),
  [(0.2, -3.5), (0.15, -0.5)]),
 (np.array([[ 0.1626096 , -0.38245842, -2.47311431],
         [ 0.12915161, -0.59713805, -1.25470091]]),
  [(0.2, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.1456479 , -0.92136374, -2.31169696],
         [ 0.05925787, -0.78726489, -1.14820265]]),
  [(0.21, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.15280379, -1.18014352, -2.54991717],
         [ 0.07794861, -0.97615943, -1.34274742]]),
  [(0.18, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.04363485, -0.90453715, -1.3507748 ],
         [ 0.16435826, -1.13805369, -2.88387266]]),
  [(0.13, -3.5), (0.14, -0.5)]),
 (np.array([[ 0.10960158, -0.91831633, -2.35135856],
         [ 0.08056244, -0.86861968, -1.36950241]]),
  [(0.11, -0.5), (0.15, -3.5)]),
 (np.array([[ 0.07587921, -0.72897394, -1.18146579],
         [ 0.06627421, -0.74122419, -0.85222919]]),
  [(0.15, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.0881808 , -0.62389479, -1.55730335],
         [ 0.09064563, -0.67253768, -1.1845178 ]]),
  [(0.13, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.04144621, -0.57473811, -3.03813772],
         [ 0.07480751, -0.55259933, -2.4403805 ]]),
  [(0.1, -3.5), (0.07, -0.5)]),
 (np.array([[ 0.08156849, -0.4981156 , -2.1652594 ],
         [ 0.01874392, -0.42969969, -3.04932019]]),
  [(0.06, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.06284478, -0.42462001, -2.17051252],
         [ 0.0781991 , -0.490554  , -1.82687224]]),
  [(0.03, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.10293894, -0.03993238, -1.64121026],
         [-0.03247089,  0.40625321, -3.00085001]]),
  [(0.02, -3.5), (0.08, -0.5)]),
 (np.array([[ 0.05727015, -0.6116956 , -1.83647162],
         [ 0.08616077, -0.5996167 , -1.51814952]]),
  [(0.0, -3.5), (0.05, -0.5)]),
 (np.array([[-0.03120812, -0.47676531, -2.96848954],
         [ 0.04176142, -0.6437127 , -0.94583103]]),
  [(-0.02, -3.5), (0.03, -0.5)]),
 (np.array([[-0.03938843, -1.00007961, -2.86052471],
         [-0.02420238, -0.89877742, -1.96812647]]),
  [(0.03, -0.5), (-0.02, -3.5)]),
 (np.array([[ 0.00487242, -0.70067641, -1.19989836],
         [-0.05316534, -0.71005149, -2.918753  ]]),
  [(-0.05, -3.5), (0.05, -0.5)]),
 (np.array([[-6.84383294e-02, -8.97074683e-01, -2.87059810e+00],
         [ 3.36671414e-04, -7.77501662e-01, -1.12504602e+00]]),
  [(0.08, -0.5), (-0.05, -3.5)]),
 (np.array([[-0.00557621,  0.18645739, -2.18397162],
         [ 0.00738101, -0.0905572 , -1.64368725]]),
  [(0.04, -0.5), (-0.02, -3.5)]),
 (np.array([[-0.01108161, -1.13395298, -1.87997772],
         [ 0.00851219, -1.02842629, -1.26028922]]),
  [(0.08, -0.5), (-0.05, -3.0)]),
 (np.array([[-0.04068665, -1.14229797, -2.80591249],
         [-0.00364348, -0.97050176, -1.97282685]]),
  [(-0.04, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.00545099, -0.86675718, -1.99520519],
         [-0.04734427, -0.98756056, -2.87217172]]),
  [(-0.03, -3.5), (0.11, -0.5)]),
 (np.array([[-0.07056703, -0.78738715, -2.92306227],
         [-0.04241552, -0.80854028, -2.63132671]]),
  [(-0.02, -3.5), (0.12, -0.5)]),
 (np.array([[-0.03504591, -0.76698932, -2.9492913 ],
         [ 0.04380556, -0.73996424, -1.74345489]]),
  [(0.01, -3.5), (0.12, -0.5)]),
 (np.array([[-0.0158578 , -0.50727503, -3.00136959],
         [-0.00643736, -0.55620363, -2.69184205]]),
  [(0.0, -3.5), (0.08, -0.5)])]

# %%
# @title
Points_to_eval_achicoria = [(np.array([[ 0.4461823 , -0.5997776 , -3.17796884],
         [ 0.4209991 , -0.59294189, -2.94202992]]),
  [(0.4, -3.5), (0.15, -0.5)]),
 (np.array([[ 0.44511713, -0.52705433, -3.15765836],
         [ 0.39497498, -0.53357306, -2.71078639]]),
  [(0.4, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.44164216, -0.50634582, -3.20029942],
         [ 0.41504151, -0.52025719, -2.9505668 ]]),
  [(0.4, -3.0), (0.15, -0.5)]),
 (np.array([[ 0.41772373, -0.48743004, -3.19712857],
         [ 0.37197482, -0.48953764, -2.69564767]]),
  [(0.125, -0.5), (0.3, -2.0)]),
 (np.array([[ 0.40192777, -0.50510137, -3.18896736],
         [ 0.38017978, -0.51020531, -2.93696646]]),
  [(0.4, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.39122873, -0.61883078, -3.1470749 ],
         [ 0.35746649, -0.59593046, -2.67958025]]),
  [(0.4, -3.0), (0.15, -0.5)]),
 (np.array([[ 0.37425765, -0.62733833, -3.14255439],
         [ 0.29103525, -0.63421369, -2.16812681]]),
  [(0.4, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.36803626, -0.6819841 , -3.12903851],
         [ 0.34865221, -0.66940296, -2.86854245]]),
  [(0.35, -4.0), (0.125, -0.5)]),
 (np.array([[ 0.32320599, -0.69857408, -2.87636555],
         [ 0.24007196, -0.66524519, -1.89355828]]),
  [(0.35, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.28259829, -0.69486687, -2.63445732],
         [ 0.26085431, -0.75199931, -2.3299446 ]]),
  [(0.35, -3.5), (0.1125, -0.5)]),
 (np.array([[ 0.23332164, -0.74574947, -1.83782176],
         [ 0.2128438 , -0.70562417, -1.38434929]]),
  [(0.3, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.2341392 , -0.71643865, -2.11760842],
         [ 0.22280094, -0.70360979, -1.8782533 ]]),
  [(0.26, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.26440719, -0.64606345, -2.64446866],
         [ 0.23812662, -0.70517326, -2.35907817]]),
  [(0.125, -0.5), (0.25, -3.5)]),
 (np.array([[ 0.22868273, -0.90837036, -2.56621818],
         [ 0.21375187, -0.93141164, -2.2559641 ]]),
  [(0.25, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.21580604, -0.66868953, -2.6165521 ],
         [ 0.19700064, -0.72968373, -2.35682405]]),
  [(0.23, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.21494706, -0.66395737, -2.61745737],
         [ 0.17369078, -0.66948132, -1.90541167]]),
  [(0.2, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.21379729, -0.65389263, -2.6417939 ],
         [ 0.18531702, -0.65583627, -1.90922777]]),
  [(0.22, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.20726049, -0.85982768, -2.54671915],
         [ 0.19389024, -0.88804511, -2.27825257]]),
  [(0.21, -3.0), (0.11, -0.5)]),
 (np.array([[ 0.19276657, -0.61365329, -2.62936142],
         [ 0.18344544, -0.68030058, -2.36723663]]),
  [(0.22, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.21941645, -0.94858173, -2.53337152],
         [ 0.20398243, -0.96766383, -2.24736253]]),
  [(0.21, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.20249375, -0.65262277, -2.59506826],
         [ 0.17541079, -0.66788944, -1.85776348]]),
  [(0.21, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.21898064, -0.47693429, -2.64902546],
         [ 0.18395558, -0.54435611, -1.88963588]]),
  [(0.22, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.22283771, -0.6455435 , -2.60824083],
         [ 0.21506269, -0.7163928 , -2.34784551]]),
  [(0.23, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.24165208, -0.61683443, -2.62747466],
         [ 0.19557533, -0.64336262, -1.86324188]]),
  [(0.23, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.24512051, -0.5602689 , -2.63532749],
         [ 0.22240701, -0.63008413, -2.357101  ]]),
  [(0.12, -0.5), (0.23, -3.5)]),
 (np.array([[ 0.22024196, -0.71068097, -1.84763767],
         [ 0.20342971, -0.69448138, -1.37845237]]),
  [(0.13, -0.5), (0.24, -3.5)]),
 (np.array([[ 0.24682182, -0.80513629, -2.55222987],
         [ 0.20095393, -0.77355999, -1.81453095]]),
  [(0.24, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.2366109 , -0.78694082, -2.31629951],
         [ 0.20897715, -0.71814997, -1.8352191 ]]),
  [(0.25, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.26338661, -0.77185903, -2.82000035],
         [ 0.23810066, -0.76423753, -2.3423795 ]]),
  [(0.24, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.26712063, -0.78865917, -2.79138803],
         [ 0.24239668, -0.78842545, -2.33154925]]),
  [(0.25, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.26634355, -0.67486805, -2.84612815],
         [ 0.24197831, -0.69940523, -2.35647989]]),
  [(0.25, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.26778972, -0.73042965, -2.83315646],
         [ 0.25556657, -0.69541076, -2.58877655]]),
  [(0.24, -3.5), (0.14, -0.5)]),
 (np.array([[ 0.26892076, -0.68816137, -2.82453837],
         [ 0.22886727, -0.71859711, -2.33999282]]),
  [(0.25, -3.5), (0.15, -0.5)]),
 (np.array([[ 0.24546758, -0.70812625, -2.82260701],
         [ 0.22170467, -0.69653029, -2.37448076]]),
  [(0.25, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.21590757, -0.61902276, -2.39613859],
         [ 0.21567884, -0.62086138, -2.39491096]]),
  [(0.25, -3.5), (0.14, -0.5)]),
 (np.array([[ 0.21427874, -0.92412702, -2.30347309],
         [ 0.21208277, -0.93751902, -2.28722268]]),
  [(0.25, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.22012391, -0.37838269, -2.66376069],
         [ 0.20819342, -0.42232342, -2.43013039]]),
  [(0.25, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.23600723, -0.47507413, -2.90459457],
         [ 0.20592895, -0.53637637, -2.37510253]]),
  [(0.24, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.22551542, -0.86525059, -2.80242215],
         [ 0.21448008, -0.82462963, -2.55946405]]),
  [(0.24, -3.5), (0.125, -0.5)]),
 (np.array([[ 0.21130062, -0.31432192, -2.41223934],
         [ 0.19670569, -0.34681255, -2.19685558]]),
  [(0.24, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.1443672 , -0.58294313, -1.16494089],
         [ 0.26745501, -0.42165756, -3.13649602]]),
  [(0.24, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.22784651, -0.39261845, -2.43487735],
         [ 0.20811611, -0.4626699 , -2.17248224]]),
  [(0.24, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.26112382, -0.85852643, -2.77954026],
         [ 0.19553994, -0.78480924, -1.58690468]]),
  [(0.24, -3.5), (0.13, -0.5)]),
 (np.array([[ 0.26144094, -0.87002438, -2.78685124],
         [ 0.23566711, -0.81613873, -2.3009001 ]]),
  [(0.25, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.24278212, -0.55524586, -2.39542223],
         [ 0.1985895 , -0.57639953, -1.69460832]]),
  [(0.24, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.1231393 , -0.69736227, -1.12948011],
         [ 0.10099039, -0.79179519, -1.04239166]]),
  [(0.25, -3.5), (0.12, -0.5)]),
 (np.array([[ 0.23006814, -0.08266475, -2.91351582],
         [ 0.1553329 , -0.42916536, -1.23074743]]),
  [(0.24, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.19807446, -0.76093499, -2.05527607],
         [ 0.18115467, -0.70850644, -1.62855086]]),
  [(0.24, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.24266007, -0.98522102, -2.77940554],
         [ 0.20754048, -0.92988025, -2.02634817]]),
  [(0.12, -0.5), (0.24, -3.5)]),
 (np.array([[ 0.19922398, -0.55574986, -2.14571589],
         [ 0.17656952, -0.55448005, -1.66779468]]),
  [(0.24, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.19314617, -0.5238445 , -2.65566577],
         [ 0.15903584, -0.56922053, -1.67007676]]),
  [(0.23, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.21622686, -1.00685455, -3.02816865],
         [ 0.16986658, -0.95354371, -2.02614411]]),
  [(0.23, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.20153903, -0.30921015, -3.1804054 ],
         [ 0.18666385, -0.38637385, -2.70126265]]),
  [(0.23, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.1526669 , -0.88163323, -3.07544309],
         [ 0.15729206, -0.85578136, -2.07786733]]),
  [(0.15, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.1390545 , -0.62251652, -2.14790736],
         [ 0.14098932, -0.60164463, -1.8990717 ]]),
  [(0.13, -3.5), (0.08, -0.5)]),
 (np.array([[ 0.1148404 , -0.48735095, -2.68332716],
         [ 0.11088348, -0.53590617, -2.15672937]]),
  [(0.11, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.09787691, -0.57658533, -2.64911377],
         [ 0.0952262 , -0.58125328, -2.16766394]]),
  [(0.08, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.0904092 , -0.42309064, -2.67953201],
         [ 0.08771587, -0.44419237, -2.19617505]]),
  [(0.05, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.05878479, -0.65169651, -2.64970168],
         [ 0.07075241, -0.62601615, -2.15171053]]),
  [(0.04, -3.5), (0.01, -0.5)]),
 (np.array([[ 0.05366203, -0.80229784, -2.08353944],
         [ 0.07038577, -0.76148973, -1.37147665]]),
  [(0.02, -3.5), (0.1, -0.5)]),
 (np.array([[ 0.02821402, -0.51468434, -2.43841449],
         [ 0.03501181, -0.49995346, -2.18577029]]),
  [(0.02, -3.5), (0.11, -0.5)]),
 (np.array([[ 0.0213106 , -0.9576964 , -2.01367795],
         [ 0.04475737, -0.86073491, -1.29496058]]),
  [(0.0, -3.5), (0.08, -0.5)]),
 (np.array([[-0.00701021, -0.12891019, -1.99894892],
         [ 0.00446259, -0.22654138, -1.54197543]]),
  [(-0.05, -3.5), (0.07, -0.5)]),
 (np.array([[-0.04302659, -1.6359443 , -2.10884158],
         [ 0.03455776, -1.23603745, -1.24199933]]),
  [(-0.05, -3.0), (0.05, -0.5)]),
 (np.array([[-0.13989042,  0.23110023, -3.20604399],
         [-0.09504292,  0.02895316, -2.6742133 ]]),
  [(-0.08, -3.5), (0.05, -0.5)]),
 (np.array([[-0.197705  ,  0.85823884, -3.08680064],
         [-0.17028149,  0.72275925, -2.881007  ]]),
  [(-0.12, -3.5), (0.0, -1.0)]),
 (np.array([[-0.24359959, -0.19509088, -3.21046772],
         [-0.0529545 , -0.46926819, -1.71601414]]),
  [(-0.25, -3.5), (0.01, -0.5)]),
 (np.array([[-0.22067138, -1.20658347, -2.68216343],
         [-0.09052431, -1.06847325, -1.68209842]]),
  [(-0.26, -3.5), (0.02, -0.5)]),
 (np.array([[-0.29185818, -1.65888793, -2.77288225],
         [-0.26180611, -1.57781389, -2.5442979 ]]),
  [(-0.3, -3.0), (0.02, -0.5)]),
 (np.array([[-0.28403596, -0.71131353, -2.89267645],
         [-0.12724107, -0.74023761, -1.84032004]]),
  [(-0.33, -3.5), (0.02, -0.5)]),
 (np.array([[-0.31761282, -1.35888009, -2.64515922],
         [-0.20095772, -1.27496894, -2.1165438 ]]),
  [(0.01, -0.5), (-0.37, -3.5)]),
 (np.array([[-0.3209178 , -0.07980193, -2.96224862],
         [-0.16518716, -0.24727232, -2.23625963]]),
  [(-0.33, -3.5), (0.0, -0.5)]),
 (np.array([[-0.34390602, -0.55542359, -2.90462015],
         [-0.16055782, -0.61105192, -2.13963376]]),
  [(0.0, -0.5), (-0.33, -3.5)]),
 (np.array([[-0.36105541,  0.37359282, -3.17720029],
         [-0.18585288,  0.02349828, -2.23076914]]),
  [(-0.36,-3.5), (0.0, -0.5)]),
 (np.array([[-0.35256618, -0.09424998, -3.20317318],
         [-0.1881275 , -0.31636785, -2.21233749]]),
  [(-0.33, -3.5), (0.01, -0.5)]),
 (np.array([[-0.36208913, -1.34332793, -2.88847975],
         [-0.19170217, -1.16259362, -1.91086259]]),
  [(-0.37, -3.5), (0.03, -0.5)]),
 (np.array([[-0.1839998 , -1.50862198, -1.6231955 ],
         [-0.26309949, -1.73649866, -2.07684049]]),
  [(-0.37, -3.0), (0.01, -0.5)]),
 (np.array([[-0.18046418, -1.21214468, -1.87410258],
         [-0.09432348, -1.11972311, -1.3873595 ]]),
  [(-0.4, -3.5), (0.01, -0.5)]),
 (np.array([[-0.33434034, -1.47277085, -2.89765412],
         [-0.18183323, -1.2280647 , -1.87962818]]),
  [(0.01, -0.5), (-0.4, -3.5)]),
 (np.array([[-0.32767029, -0.01583758, -3.03092165],
         [-0.18997469, -0.23690183, -2.23295537]]),
  [(-0.42, -3.5), (0.03, -0.5)]),
 (np.array([[-0.39333673,  0.79396933, -3.19005769],
         [-0.19307903,  0.29805857, -2.25193244]]),
  [(-0.35, -3.5), (0.05, -0.5)]),
 (np.array([[-0.37577392, -1.385262  , -2.94647377],
         [-0.37170207, -1.39376892, -2.93554517]]),
  [(-0.37, -3.5), (0.01, -0.5)]),
 (np.array([[-0.18560627, -1.21663783, -1.8885137 ],
         [-0.14309219, -1.13595961, -1.66164446]]),
  [(-0.38, -3.5), (0.0, -0.5)]),
 (np.array([[-0.24608444,  0.11900067, -2.50259246],
         [-0.19214498,  0.0228057 , -2.22949164]]),
  [(-0.37, -3.5), (0.02, -0.5)]),
 (np.array([[-0.36142761, -1.54663458, -2.81635236],
         [-0.23446363, -1.36579702, -2.10358158]]),
  [(-0.4, -3.5), (0.02, -0.5)]),
 (np.array([[-0.15729495, -0.77082921, -1.86429459],
         [-0.05670608, -0.78959408, -1.30972499]]),
  [(-0.4, -3.5), (0.02, -0.5)]),
 (np.array([[-0.25743763,  0.47753724, -2.47501014],
         [-0.16534079,  0.23210824, -2.00881858]]),
  [(-0.43, -3.5), (0.05, -0.5)]),
 (np.array([[-0.22713746, -0.81364009, -2.13350498],
         [-0.16515717, -0.81899336, -1.85643874]]),
  [(-0.45, -3.5), (0.05, -0.5)]),
 (np.array([[-0.30678087, -0.99382033, -1.18613886],
         [-0.3076687 , -0.99527141, -1.16874912]]),
  [(0.02, -0.5), (-0.46, -3.5)]),
 (np.array([[-0.15335547, -0.94351686, -1.55633655],
         [-0.08720193, -0.92346894, -1.22355309]]),
  [(-0.5, -3.5), (0.03, -0.5)]),
 (np.array([[-0.07587289, -0.63271178, -1.42118993],
         [-0.41504174, -0.50717077, -3.23398464]]),
  [(-0.47, -3.5), (0.03, -0.5)]),
 (np.array([[-0.3818359 , -0.9074413 , -3.13750538],
         [-0.03524423, -0.79938837, -1.076861  ]]),
  [(-0.48, -3.5), (0.05, -0.5)]),
 (np.array([[-0.19194555, -0.59424602, -2.1950796 ],
         [-0.14853753, -0.62825959, -1.90644004]]),
  [(-0.45, -3.5), (0.02, -0.5)]),
 (np.array([[-0.14366955, -0.14133479, -1.9938725 ],
         [-0.06791662, -0.22095731, -1.5323939 ]]),
  [(-0.45, -3.5), (0.03, -0.5)]),
 (np.array([[-0.24842699, -0.9307223 , -2.34473037],
         [-0.18980419, -0.92953103, -2.03784319]]),
  [(-0.47, -3.5), (0.05, -0.5)]),
 (np.array([[-0.17231229,  0.5722178 , -2.16070653],
         [-0.02752029,  0.1901767 , -1.53304348]]),
  [(-0.4, -3.5), (0.08, -0.5)]),
 (np.array([[-0.19314786, -0.62682411, -2.16979939],
         [-0.155747  , -0.60717803, -1.93741385]]),
  [(-0.4, -3.5), (0.07, -0.5)]),
 (np.array([[-0.26855136, -0.99391967, -2.33088057],
         [-0.19480484, -0.99338075, -2.01348245]]),
  [(-0.4, -3.5), (0.05, -0.5)]),
 (np.array([[-0.28152673, -0.39345709, -2.48832682],
         [-0.21295637, -0.46187488, -2.18037436]]),
  [(-0.4, -3.5), (0.06, -0.5)]),
 (np.array([[-0.29607127, -1.57944394, -1.98842983],
         [-0.28456459, -1.57592383, -1.9393464 ]]),
  [(-0.5, -3.5), (0.03, -0.5)])]

# %%
#Enlace al colab: https://colab.research.google.com/drive/1V-C0TkePSMpP_T9ZFG03iUwqTQ67OqkB?usp=sharing
import math
def calculate_angles(accel_data):
    pitch = math.atan2(accel_data.y, math.sqrt(accel_data.x**2 + accel_data.z**2))
    roll = math.atan2(-accel_data.x, math.sqrt(accel_data.y**2 + accel_data.z**2))

    # A grados sexagesimales
    pitch_deg = math.degrees(pitch)
    roll_deg = math.degrees(roll)

    return pitch_deg, roll_deg

def rotate_point_cloud_y(points, pitch_angle):
    # Matriz de rotación
    R_x = np.array([
        [1, 0, 0],
        [0, np.cos(pitch_angle), -np.sin(pitch_angle)],
        [0, np.sin(pitch_angle), np.cos(pitch_angle)]
    ])

    rotated_points = points @ R_x.T
    return rotated_points

# %%
###############################################################
#             Código para acceder a las imágenes
#                    Base de datos
##############################################################
############################################################

###Descargar los videos de aquí: https://1drv.ms/f/c/342772be9890904e/EiiBYG-iEABKs39rIRELs_cBkAD70GmpMKFtG8UYgAAAAQ?e=ksSqUY

from google.colab import drive #Para probarlo subí el video a mi google drive por lo que lo agregué estas líneas
drive.mount('/gdrive')

# !pip install pyrealsense2
import pyrealsense2 as rs
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time
from IPython.display import display, Markdown

pipeline = rs.pipeline()
config = rs.config()


############ Escribir si se evaluará el video estándar o el de Achicoria ##########
#Si es el de Achicoria

Points_to_eval = Points_to_eval_achicoria
config.enable_device_from_file('/gdrive/MyDrive/Electrónica/Tesis/Planta_alta.bag', repeat_playback=False) #En este caso estoy abriendolo desde mi google drive

#Si es el estandar comentar el anterior y descomentar este

#Points_to_eval = Points_to_eval_estandar
#config.enable_device_from_file('Videos/Corriendo_y_arrastrando2.bag', repeat_playback=False)


config.enable_stream(rs.stream.depth)
config.enable_stream(rs.stream.accel)
config.enable_stream(rs.stream.gyro)
pipeline.start(config)
profile = pipeline.get_active_profile()
playback = profile.get_device().as_playback()
playback.set_real_time(False)  # Esto permite avanzar frame por frame sin flujo en tiempo real
depth_stream = profile.get_stream(rs.stream.depth)
intrinsics = depth_stream.as_video_stream_profile().get_intrinsics()
pc = rs.pointcloud()

frame_number = 0  # Primer frame

try:
    for _ in range(frame_number):
        frames = pipeline.wait_for_frames()
    while True:
        frames = pipeline.wait_for_frames()
        frame_number += 1
        depth_frame = frames.get_depth_frame()
        accel_frame = frames.first_or_default(rs.stream.accel)

        if not depth_frame:
            print("No se pudo obtener el frame de profundidad")
            continue
        # Procesamiento de datos de profundidad y aceleración
        depth_image = np.asanyarray(depth_frame.get_data())
        accel_data = accel_frame.as_motion_frame().get_motion_data()
        depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET)
        points = pc.calculate(depth_frame)
        pc.map_to(depth_frame)
        v, t = points.get_vertices(), points.get_texture_coordinates()
        verts = np.asanyarray(v).view(np.float32).reshape(-1, 3)
        pitch, roll = calculate_angles(accel_data)
        pitch_angle = np.radians(-90 - pitch)

        MIN_DISTANCE = 0.001
        MAX_DISTANCE = 3.5
        valid_vertices = []
        for i, vert in enumerate(verts):
            if abs(vert[0]) >= MIN_DISTANCE and abs(vert[1]) >= MIN_DISTANCE and (abs(vert[2]) >= MIN_DISTANCE and abs(vert[2]) <= MAX_DISTANCE):
                valid_vertices.append([vert[0], -vert[1], -vert[2]])  # Flip y and z axes
        rotated_vertices = rotate_point_cloud_y(valid_vertices, pitch_angle)

        # Grafica

        display(Markdown(f"### Frame {frame_number}: Procesado."))
        xz_points = rotated_vertices[:, [0, 2]]
        xz_estimated = Points_to_eval[frame_number][0]
        [(x1, z1), (x2, z2)] = Points_to_eval[frame_number][1]
        plt.figure(figsize=(8, 6))
        plt.scatter(xz_points[:, 0], xz_points[:, 1], s=1, alpha=0.5)
        plt.scatter(xz_estimated[:,0], xz_estimated[:,2], color='green', s=50)
        plt.scatter([x1, x2], [z1, z2], color='red', s=50)
        plt.plot([x1, x2], [z1, z2], color='red', label="Línea esperada")
        plt.plot(xz_estimated[:,0], xz_estimated[:,2], color='green', label="Línea estimada")
        plt.xlabel("X (metros)")
        plt.ylabel("Z (metros)")
        plt.title("Vista superior (proyección en el plano XZ)")
        plt.axis("equal")
        plt.legend()
        plt.grid(True)
        plt.show()


        print("Escribe (sí) para pasar al siguiente frame y (no) para terminar:")

        # Capturar la entrada
        confirm = input().strip().lower()

        if confirm == 'sí':
          print("Procesando frame...")
          #continuar
        else:
          print("Saliendo del proceso.")
          break

finally:
    pipeline.stop()
# Out:
# Mounted at /gdrive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 30.4 MB/s eta 0:00:00
# ...
# ### Frame 1: Procesado.
# Escribe (sí) para pasar al siguiente frame y (no) para terminar:
# sí
# Procesando frame...
# ### Frame 2: Procesado.
# Escribe (sí) para pasar al siguiente frame y (no) para terminar:
# sí
# Procesando frame...
# ### Frame 3: Procesado.
# Escribe (sí) para pasar al siguiente frame y (no) para terminar:
# no
# Saliendo del proceso.
